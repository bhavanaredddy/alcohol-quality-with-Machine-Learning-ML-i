# %% [markdown]
# # Wine_Quality Prediction
# ## To develop a Machine learning model to predict the quality of the alcohol using the features in dataset.

# %% [markdown]
# # data description
#     Density-It describes the density of the alcohol(0.79g/ml)
#     pH-ph value of the alcohol
#     sulphates-The sulphate percentage in alcohol
#     Quality_category-whether the quality is low or high.
#     alcohol-alcohol range

# %% [markdown]
# # Data Types
#     a collection or grouping of data values, usually specified by a set of possible values, a set of allowed operations on these values, a representation of these values as machine types.list,strings,tuple etc are some data types.

# %% [markdown]
# # Importing modules

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("alcohol-quality-data.csv")

# %%
df.head()
# Out:
#   Quality_Category  density  pH  sulphates  alcohol
# 0              Low    1.001   3       0.45      8.8
# 1              Low    0.994   3       0.49      9.5
# 2              Low    0.995   3       0.44     10.1
# 3              Low    0.996   3       0.40      9.9
# 4              Low    0.996   3       0.40      9.9

# %%
df.tail()
# Out:
#      Quality_Category  density  pH  sulphates  alcohol
# 4893              Low    0.991   3       0.50     11.2
# 4894              Low    0.995   3       0.46      9.6
# 4895              Low    0.993   3       0.46      9.4
# 4896             High    0.989   3       0.38     12.8
# 4897              Low    0.989   3       0.32     11.8

# %%
df.columns
# Out:
# Index(['Quality_Category', 'density', 'pH', 'sulphates', 'alcohol'], dtype='object')

# %%
df.describe()
# Out:
#            density           pH    sulphates      alcohol
# count  4898.000000  4898.000000  4898.000000  4898.000000
# mean      0.994049     3.031850     0.489847    10.514516
# std       0.003008     0.175618     0.114126     1.230885
# min       0.987000     3.000000     0.220000     8.000000
# 25%       0.992000     3.000000     0.410000     9.500000
# 50%       0.994000     3.000000     0.470000    10.400000
# 75%       0.996000     3.000000     0.550000    11.400000
# max       1.039000     4.000000     1.080000    14.200000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Quality_Category  4898 non-null   object
#  1   density           4898 non-null   float64
#  2   pH                4898 non-null   int64
#  3   sulphates         4898 non-null   float64
#  4   alcohol           4898 non-null   float64
# dtypes: float64(3), int64(1), object(1)
# memory usage: 191.5+ KB

# %% [markdown]
# # Identifying Null values

# %%
df.isnull().sum()
# Out:
# Quality_Category    0
# density             0
# pH                  0
# sulphates           0
# alcohol             0
# dtype: int64

# %%
df.shape
# Out:
# (4898, 5)

# %% [markdown]
# # Identifying Outliers
#      An oulier is a data point in a data set that is distant from all other observations.
#      Hence we can find the outlier using boxplot

# %%
# getting outlier for density feature
sns.boxplot(df['density'])
# Out:
# <AxesSubplot:xlabel='density'>

# %% [markdown]
# # Identifying the discrete/continous feature

# %%
categorical = df.select_dtypes(include=[np.object])
print("Number of categorical variables:",categorical.shape[1])

numerical = df.select_dtypes(include=[np.float64,np.int64])
print("Numeber of numerical variables:",numerical.shape[1])
# Out:
# Number of categorical variables: 1
# Numeber of numerical variables: 4

# %% [markdown]
# # Univariate analysis

# %%
sns.countplot(df['Quality_Category'])
# Out:
# <AxesSubplot:xlabel='Quality_Category', ylabel='count'>

# %%
sns.countplot(df['density'])
# Out:
# <AxesSubplot:xlabel='density', ylabel='count'>

# %%
sns.countplot(df['pH'])
# Out:
# <AxesSubplot:xlabel='pH', ylabel='count'>

# %%
sns.countplot(df['sulphates'])
# Out:
# <AxesSubplot:xlabel='sulphates', ylabel='count'>

# %%
sns.countplot(df['alcohol'])
# Out:
# <AxesSubplot:xlabel='alcohol', ylabel='count'>

# %%
alc = df['alcohol'].value_counts()
alc.plot(kind="pie",figsize=(8,5))
# Out:
# <AxesSubplot:ylabel='alcohol'>

# %%
den = df['density'].value_counts()
den.plot(kind="pie",figsize=(8,5))
# Out:
# <AxesSubplot:ylabel='density'>

# %%
pH = df['pH'].value_counts()
pH.plot(kind="pie",figsize=(8,5))
# Out:
# <AxesSubplot:ylabel='pH'>

# %%
category = df['Quality_Category'].value_counts()
category.plot(kind="pie",figsize=(8,5))
# Out:
# <AxesSubplot:ylabel='Quality_Category'>

# %%
sns.boxplot(df['density'])
# Out:
# <AxesSubplot:xlabel='density'>

# %%
sns.displot(df['density'])

# %%
sulphates = df['sulphates'].value_counts()
sulphates.plot(kind="pie",figsize=(8,5))
# Out:
# <AxesSubplot:ylabel='sulphates'>

# %%
sns.boxplot(df['pH'])
# Out:
# <AxesSubplot:xlabel='pH'>

# %%
sns.boxplot(df['sulphates'])
# Out:
# <AxesSubplot:xlabel='sulphates'>

# %%
sns.boxplot(df['alcohol'])
# Out:
# <AxesSubplot:xlabel='alcohol'>

# %%
sns.displot(df['pH'])

# %%
sns.displot(df['sulphates'])

# %%
sns.displot(df['alcohol'])

# %%
alc = df['alcohol'].value_counts()
sns.barplot(alc.index,alc.values)
plt.xticks(rotation=90)
plt.figure(figsize=(8,5))
plt.show()

# %%
pH = df['pH'].value_counts()
sns.barplot(pH.index,pH.values)
plt.xticks(rotation=90)
plt.figure(figsize=(8,5))
plt.show()

# %%
Is = df['density'].value_counts()
Is.plot(kind="bar",figsize=(8,5),color = 'g')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Overall observations from EDA:
# ## UNIVARIATE ANALYSIS:
#      1.The alcohol dataset has 4898 rows and 5 columns.
#      2.There are 1 categorical variables and 4 numerical variables
#      categoricalvalue:In general,categorical data has values and observations which can be sorted into categories or groups.
#      Numerical value:A numeric value contains only numbers, a sign (leading or trailing), and a single decimal point.
#      3.There are no unique columns in the dataset.
#      4.There are no null values in any category of the dataset.
#      5.we have more low Quality_category.Hence the Quality_Category is target function.
#      6.There is no outliers in alcohol.
#      7.we have less number od data with pH value 4

# %% [markdown]
# # Bivariate analysis:

# %%
gp1 = df.groupby('pH')['density'].value_counts()
gp1.plot(kind="bar",figsize=(10,8))
print(gp1)
# Out:
# pH  density
# 3   0.992      591
#     0.993      591
#     0.991      516
#     0.994      510
#     0.995      491
#     0.996      421
#     0.998      377
#     0.990      354
#     0.997      344
#     0.999      207
#     0.989      158
#     1.000      124
#     1.001       22
#     0.988       17
#     0.987        8
#     1.002        6
#     1.003        2
#     1.010        2
#     1.039        1
# 4   0.995       29
#     0.992       23
#     0.993       23
#     0.994       18
#     0.996       13
#     0.998       12
#     0.990        9
#     0.991        9
#     0.989        8
#     0.997        7
#     0.999        4
#     1.000        1
# Name: density, dtype: int64

# %%
gp2 = df.groupby('pH')['density'].value_counts()
gp2.plot(kind="pie",figsize=(10,8))
print(gp2)
# Out:
# pH  density
# 3   0.992      591
#     0.993      591
#     0.991      516
#     0.994      510
#     0.995      491
#     0.996      421
#     0.998      377
#     0.990      354
#     0.997      344
#     0.999      207
#     0.989      158
#     1.000      124
#     1.001       22
#     0.988       17
#     0.987        8
#     1.002        6
#     1.003        2
#     1.010        2
#     1.039        1
# 4   0.995       29
#     0.992       23
#     0.993       23
#     0.994       18
#     0.996       13
#     0.998       12
#     0.990        9
#     0.991        9
#     0.989        8
#     0.997        7
#     0.999        4
#     1.000        1
# Name: density, dtype: int64

# %%
gp3 = df.groupby('Quality_Category')['pH'].value_counts()
gp3
# Out:
# Quality_Category  pH
# High              3     1017
#                   4       43
# Low               3     3725
#                   4      113
# Name: pH, dtype: int64

# %%
sns.barplot(x='sulphates',y='pH',hue='density',data=df)
# Out:
# <AxesSubplot:xlabel='sulphates', ylabel='pH'>

# %%
gp4 = df.groupby(['alcohol','pH'])['Quality_Category'].value_counts()
gp4.plot(kind="bar",figsize=(20,10),subplots=True)
print(gp4)
# Out:
# alcohol  pH  Quality_Category
# 0        0   1                    2
# 1        0   1                    3
# 2        0   1                    8
#              0                    1
# 3        0   1                   20
#                                  ..
# 56       0   0                    3
# 57       0   0                    4
#              1                    1
# 58       0   0                    1
# 59       0   0                    1
# Name: Quality_Category, Length: 164, dtype: int64

# %%
gp5 = df.groupby(['Quality_Category','pH'])['alcohol'].mean()
gp5.plot(kind='bar',figsize=(10,8))
print(gp5)
# Out:
# Quality_Category  pH
# High              3     11.415929
#                   4     11.427907
# Low               3     10.260081
#                   4     10.441593
# Name: alcohol, dtype: float64

# %%
sns.barplot(x='Quality_Category',y='density',hue='alcohol',data=df)
# Out:
# <AxesSubplot:xlabel='Quality_Category', ylabel='density'>

# %%
gp6 = df.groupby(['Quality_Category','pH'])['sulphates'].mean()
gp6.plot(kind='bar',figsize=(10,8))
print(gp6)
# Out:
# Quality_Category  pH
# High              3     0.498574
#                   4     0.537209
# Low               3     0.485125
#                   4     0.548938
# Name: sulphates, dtype: float64

# %%
gp7 = df.groupby(['pH'])['Quality_Category'].value_counts()
gp7.plot(kind="bar",figsize=(20,10),subplots=True)
print(gp7)
# Out:
# pH  Quality_Category
# 3   Low                 3725
#     High                1017
# 4   Low                  113
#     High                  43
# Name: Quality_Category, dtype: int64

# %%
gp8 = df.groupby(['pH'])['density','Quality_Category'].mean()
gp8.plot(kind="bar",figsize=(20,10),subplots=True)
print(gp8)
# Out:
#      density
# pH
# 3   0.994056
# 4   0.993859

# %%
gp9 = df.groupby(['pH'])['density','sulphates'].mean()
gp9.plot(kind="bar",figsize=(20,10),subplots=True)
print(gp9)
# Out:
#      density  sulphates
# pH
# 3   0.994056   0.488009
# 4   0.993859   0.545705

# %%
gp10 = df.groupby(['pH'])['density','sulphates'].mean()
gp10.plot(kind="pie",figsize=(20,10),subplots=True)
print(gp10)
# Out:
#      density  sulphates
# pH
# 0   7.045972  25.789962
# 1   6.858974  31.564103

# %%
gp11 = df.groupby(['Quality_Category'])['pH','alcohol','sulphates','density'].mean()
gp11.plot(kind="bar",figsize=(20,10),subplots=True)
print(gp11)
# Out:
#                         pH    alcohol  sulphates   density
# Quality_Category
# 0                 0.040566  31.164151  26.988679  5.438679
# 1                 0.029442  19.655810  25.693590  7.482282

# %%
sns.barplot(y='pH',hue='density',data=df)
# Out:
# <AxesSubplot:ylabel='pH'>

# %% [markdown]
# # Overall observations from EDA:
# ## BIVARIATE ANALYSIS:
#      Bivariate analysis is a statistical method examining how two different things are related. The bivariate analysis aims to determine if there is a statistical link between the two variables.
#      1.Mostly the pH value is 3 or 4 which depicts that the alcohol is acidic.
#      2.The pH of 3 is ten times more acidic than a pH of 4.Mostly the pH value is 3 than 4.
#      3.This suggests that the more acidic nature of the wine makes its poor.
#      4.Alcohol is important feature among remaining features in the dataset.
#      5.The percentage of the alcohol is 20 times greater than the percentage of sulphate in the whole Quantity of alcohol.
#      6.The density of the alcohol must be nearer or equal to 1 kg/m^3.
#      7.The features in the Quality_Category is continous in nature.
#      8.alcohol is one of the important feature to predict the quality.

# %% [markdown]
# # Label encoding values
#    Label encoding is a technique used in machine learning and data analysis to convert categorical variables into numerical format.

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
df['density'] = le.fit_transform(df['density'])
df['pH'] = le.fit_transform(df['pH'])
df['sulphates'] = le.fit_transform(df['sulphates'])
df['alcohol'] = le.fit_transform(df['alcohol'])
df['Quality_Category'] = le.fit_transform(df['Quality_Category'])

# %%
df.head()
# Out:
#    Quality_Category  density  pH  sulphates  alcohol
# 0                 1       14   0         22        5
# 1                 1        7   0         26       12
# 2                 1        8   0         21       18
# 3                 1        9   0         17       16
# 4                 1        9   0         17       16

# %%
df.shape
# Out:
# (4898, 5)

# %%
plt.figure(figsize=(20,10))
df_lt = df.corr(method = "pearson")
df_lt1 = df_lt.where(np.tril(np.ones(df_lt.shape)).astype(np.bool))
sns.heatmap(df_lt1,annot=True,cmap="coolwarm")
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Train test split of the data

# %%
target = df['Quality_Category']
data = df.drop("Quality_Category",axis=1)

# %%
target.shape
# Out:
# (4898,)

# %%
data.shape
# Out:
# (4898, 4)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(data,target,test_size=0.20,random_state=101)

# %% [markdown]
# # Predictive Churn model - description
# After Exploratory data analysis, We move on to the important part of building model.
# The data has been preprocessed using sklearn library.

# %% [markdown]
# # Model building
# ## Logistic regression

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
x_pred = lr.predict(X_train)
y_pred = lr.predict(X_test)

# %%
from sklearn.metrics import plot_confusion_matrix,accuracy_score
print("Training accuracy:",accuracy_score(y_train,x_pred))
print("Testing accuracy:",accuracy_score(y_test,y_pred))
# Out:
# Training accuracy: 0.8034711587544666
# Testing accuracy: 0.810204081632653

# %%
plot_confusion_matrix(lr,X_test,y_test,values_format='d')

# %% [markdown]
# # Random forest classifer

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=100)
rf.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
x_pred = rf.predict(X_train)
y_pred = rf.predict(X_test)

# %%
print("Training accuracy:",accuracy_score(y_train,x_pred))
print("Testing accuracy:",accuracy_score(y_test,y_pred))
# Out:
# Training accuracy: 0.9640122511485452
# Testing accuracy: 0.8408163265306122

# %%
plot_confusion_matrix(rf,X_test,y_test,values_format='d')

# %% [markdown]
# # Support vector machines

# %%
from sklearn.svm import SVC
sv = SVC()
sv.fit(X_train,y_train)
# Out:
# SVC()

# %%
x_pred = sv.predict(X_train)
y_pred = sv.predict(X_test)

# %%
print("Training accuracy:",accuracy_score(y_train,x_pred))
print("Testing accuracy:",accuracy_score(y_test,y_pred))
# Out:
# Training accuracy: 0.7970903522205207
# Testing accuracy: 0.8020408163265306

# %%
plot_confusion_matrix(sv,X_test,y_test,values_format='d')

# %% [markdown]
# # Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
nb = GaussianNB()
nb.fit(X_train,y_train)
# Out:
# GaussianNB()

# %%
x_pred = nb.predict(X_train)
y_pred = nb.predict(X_test)

# %%
print("Training accuracy:",accuracy_score(y_train,x_pred))
print("Testing accuracy:",accuracy_score(y_test,y_pred))
# Out:
# Training accuracy: 0.7725880551301685
# Testing accuracy: 0.7622448979591837

# %%
plot_confusion_matrix(nb,X_test,y_test,values_format='d')

# %% [markdown]
# # KNN Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=15)
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=15)

# %%
x_pred = knn.predict(X_train)
y_pred = knn.predict(X_test)

# %%
print("Training accuracy:",accuracy_score(y_train,x_pred))
print("Testing accuracy:",accuracy_score(y_test,y_pred))
# Out:
# Training accuracy: 0.8208269525267994
# Testing accuracy: 0.8030612244897959

# %%
plot_confusion_matrix(knn,X_test,y_test,values_format='d')

# %% [markdown]
# # Decision tree classifier

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier()
dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
x_pred = dt.predict(X_train)
y_pred = dt.predict(X_test)

# %%
print("Training accuracy:",accuracy_score(y_train,x_pred))
print("Testing accuracy:",accuracy_score(y_test,y_pred))
# Out:
# Training accuracy: 0.9640122511485452
# Testing accuracy: 0.8091836734693878

# %%
plot_confusion_matrix(dt,X_test,y_test,values_format='d')

# %% [markdown]
# # Neural networks

# %%
from sklearn.neural_network import MLPClassifier
nn = MLPClassifier()
nn.fit(X_train,y_train)
# Out:
# MLPClassifier()

# %%
x_pred = nn.predict(X_train)
y_pred = nn.predict(X_test)

# %%
print("Training accuracy:",accuracy_score(y_train,x_pred))
print("Testing accuracy:",accuracy_score(y_test,y_pred))
# Out:
# Training accuracy: 0.7988769780500256
# Testing accuracy: 0.8061224489795918

# %%
plot_confusion_matrix(nn,X_test,y_test,values_format='d')

# %% [markdown]
# # Selection of variables

# %% [markdown]
# # Performance of ML model
# ## Logistic regression
#     1.This model performs very well in both training as well as testing data.
#     2.It gives an accuracy of 80% in training set and 81% in testing set.
#     3.It is the best fit model.
# ## Random forest classifer
#     1.This model performs very well in training set but moderately in testing set.
#     2.This algorithm makes the model to be overfitted in the dataset.
#     3.It gives an accuarcy of 96% in training set and only 84% in testing set.
#     4.This model overfits so we will not be proceeding with this model.
# ## Support vector machines
#     1.it is a classification problem.
#     2..It gives an accuarcy of 79% in training set and only 80% in testing set.
# ## Navie Bayes
#     1.It is one of the simplest classification algorithm.
#     2.It gives an accuracy of 77% in train set and 74% in testing set.
#     3.It is a well performed model.
# ## KNN Classifier
#     1.It is also one of the best and efficient Classification algorithm.
#     2.It gives an accuracy of 82% in training set which is the best and 70% in test set.
#     3.We can also proceed with this model.
# ## Decision tree classifier
#      1.This model performs very well in training set but moderately in testing set.
#      2.This algorithm makes the model to be overfitted in the dataset.
#      3.It gives an accuarcy of 96% in training set and only 80% in testing set.
#      4.This model overfits so we will not be proceeding with this model.
# ## Neural Networks
#     1.MLPClassifier is a deep learning algorithm for Machine learning which uses neural network for prediction.
#     2.It gives an accuracy of 79% in train set and 80% in test set.
#     3.One of the well-fitted and best model.

# %% [markdown]
# # ROC CURVE

# %%
from sklearn.metrics import classification_report
cr = classification_report(y_test,y_pred)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.53      0.22      0.31       195
#            1       0.83      0.95      0.89       785
#
#     accuracy                           0.81       980
#    macro avg       0.68      0.58      0.60       980
# weighted avg       0.77      0.81      0.77       980

# %%
from sklearn.metrics import roc_curve
pred_prob1 = lr.predict_proba(X_test)
pred_prob2 = rf.predict_proba(X_test)
pred_prob3 = nb.predict_proba(X_test)
pred_prob4 = knn.predict_proba(X_test)
pred_prob5 = dt.predict_proba(X_test)
pred_prob6 = nn.predict_proba(X_test)
fpr1,tpr1,thresh1 = roc_curve(y_test,pred_prob1[:,1],pos_label=1)
fpr2,tpr2,thresh2 = roc_curve(y_test,pred_prob2[:,1],pos_label=1)
fpr3,tpr3,thresh3 = roc_curve(y_test,pred_prob3[:,1],pos_label=1)
fpr4,tpr4,thresh4 = roc_curve(y_test,pred_prob4[:,1],pos_label=1)
fpr5,tpr5,thresh5 = roc_curve(y_test,pred_prob5[:,1],pos_label=1)
fpr6,tpr6,thresh6 = roc_curve(y_test,pred_prob6[:,1],pos_label=1)

# %%
random_prob = [0 for i in range(len(y_test))]
p_fpr , p_tpr , _ = roc_curve(y_test,random_prob, pos_label=1)

# %%
plt.figure(figsize=(20,10))
plt.plot(fpr1, tpr1, linestyle='--',color='orange', label='Logistic Regression')
plt.plot(fpr2, tpr2, linestyle='--',color='green', label='RandomForest Classifier')
plt.plot(fpr3, tpr3, linestyle='--',color='yellow', label='Naive Bayes')
plt.plot(fpr4, tpr4, linestyle='--',color='black', label='KNN')
plt.plot(fpr5, tpr5, linestyle='--',color='violet', label='Decsion Tree Classifier')
plt.plot(fpr6, tpr6, linestyle='--',color='grey', label='Neural Networks')
plt.plot(p_fpr, p_tpr, linestyle='--', color='blue')
plt.title('ROC curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive rate')
plt.legend(loc='best')

# %% [markdown]
# # Keyfactors and thier importance:
#     1.The keyfactor is the *Alcohol Percentage.*
#     2.This suggests the improve in alcohol quality.
#     3.There is a clear increasing trend here, as the levels are increasing we see the target percentage improves.
#     4.For feature sulphates, we see that: On average, the levels have less than the overall target percentage.Only the third  level has the percentage  of the targets slightly more than the overall train target percentage.This feature may not be that relevant or important for predicting the quality of alcohol.
#     5.For feature pH, we see that:There is a slight  trend. As the levels are increasing the target percentage is also incr-easing but the increase is not much compared to the overall target percentage.This suggests that this feature is slight-ly important for predicting the quality of alcohol.
#     6.For feature density, we see that:Similar to chlorides here also we see initial levels show a higher train target perc-entage compared to the overall train target percentage.This suggests that this could be a slightly important variable..

# %% [markdown]
# # Requirements that makes Quality of alcohol HIGH:
#      Alcohol has three major characteristics; it is a nutrient (energy source), a psycho-active drug and a toxin.
#      The pH value of alcohol is 7.33, it is a weak acid.
#      The density of alcohol is 780 kg/m3.

# %% [markdown]
# # Conclusion:
#     Alcohol dataset is provided to predict the Quality_Category of the customer.
#     Exploratory data analysis gives an more perfect view of the data.
#     Logistic regression is the best fit.Hence it can increase the quality of alcohol.
#     By making mentioned requirements above will make sure that it will increase  of the alcohol quality.
